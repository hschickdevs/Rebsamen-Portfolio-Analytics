# %%
import pandas as pd
from pathlib import Path

# %%
# Load dataframe
df = pd.read_excel(Path("assets/Rebsamen Holdings 082222.xls"))

# %%
# Clean Dataframe

# 1. Reformat header as 2nd row
updated_header = df.iloc[1] #grab the second row for the header
df = df[2:]
df.columns = updated_header
df
# Out:
# 1  Security ID USIP/ISIN/SEDOL Account Number Account Nickname/Title  \
# 2         GOOG       02079K107        ***8747               REBSAMEN
# 3         AMZN       023135106        ***8747               REBSAMEN
# 4          AWK       030420103        ***8747               REBSAMEN
# 5         AAPL       037833100        ***8747               REBSAMEN
# 6          ADM       039483102        ***8747               REBSAMEN
# 7          WRB       084423102        ***8747               REBSAMEN
# 8          CMG       169656105        ***8747               REBSAMEN
# 9         COST       22160K105        ***8747               REBSAMEN
# 10         DVN       25179M103        ***8747               REBSAMEN
# 11        DLTR       256746108        ***8747               REBSAMEN
# 12         EXR       30225T102        ***8747               REBSAMEN
# 13         XOM       30231G102        ***8747               REBSAMEN
# 14         FCX       35671D857        ***8747               REBSAMEN
# ...
